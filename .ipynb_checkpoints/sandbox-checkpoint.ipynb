# %%
from pandas.io.json import json_normalize
import json
import urllib.request
import pandas as pd


# API Key
# replace YOUR_API_KEY with the API key you got from sec-api.io after sign up
TOKEN = "6b2487e582e186708c492280e1638c3d7888da05699bc227fe70cbd8668fe1ad"
# API endpoint
API = "https://api.sec-api.io?token=" + TOKEN


def get_query(ticker):
    # Define the filter parameters
    filter = "ticker:" + ticker + " AND formType:\"S-1\""

    # Start with the first filing. Increase it when paginating.
    # Set to 10000 if you want to fetch the next batch of filings. Set to 20000 for the next and so on.
    start = 0
    # Return 10,000 filings per API call
    size = 100
    # Sort in descending order by filedAt
    sort = [{"filedAt": {"order": "desc"}}]

    payload = {
        "query": {"query_string": {"query": filter}},
        "from": start,
        "size": size,
        "sort": [
            {
                "filedAt": {
                    "order": "desc"
                }
            }
        ]
    }

    # Format your payload to JSON bytes
    jsondata = json.dumps(payload)
    jsondataasbytes = jsondata.encode('utf-8')   # needs to be bytes

    # Instantiate the request
    req = urllib.request.Request(API)

    # Set the correct HTTP header: Content-Type = application/json
    req.add_header('Content-Type', 'application/json; charset=utf-8')
    # Set the correct length of your request
    req.add_header('Content-Length', len(jsondataasbytes))

    # Send the request to the API
    response = urllib.request.urlopen(req, jsondataasbytes)

    # Read the response
    res_body = response.read()
    # Transform the response into JSON
    filingsJson = json.loads(res_body.decode("utf-8"))

    return filingsJson['filings']
# Out:
# Duplicate key in file '/Users/sharan/.matplotlib/matplotlibrc' line #39.

# %%
result = (get_query("DATA"))

# %%
df = json_normalize(result)

# %%
df = df[df['formType'] == "S-1"]
df = df.sort_values("filedAt", ascending=False).reset_index(drop=True)
# Out:
# Index(['cik', 'companyName', 'filedAt', 'formType', 'id', 'linkToHtml',
#        'linkToTxt', 'ticker'],
#       dtype='object')

# %%
df['linkToHtml'][0]

# %%
df['linkToHtml'][1]
# Out:
# 'https://www.sec.gov/Archives/edgar/data/1303652/0001193125-14-100363-index.htm'

# %%
df['linkToHtml'][2]
# Out:
# 'https://www.sec.gov/Archives/edgar/data/1303652/0001193125-13-413502-index.htm'

# %%
tickers= pd.read_excel('internet-IPOs.xlsx')
tickers
# Out:
#                           IPO name  Offer date   SIC Ticker  Unit  Offer price
# 0                    Cisco Systems    19900216  3577   CSCO     1       18.000
# 1          Valassis Communications    19920311  2752    VCI     1       17.000
# 2                   America Online    19920319  4822   AMER     1       11.500
# 3                           Olicom    19921022  7372  OLCMF     1       14.000
# 4                  Micro Warehouse    19921210  5961   MWHS     1       18.000
# 5                      FutureMedia    19930819  7812  FMDAY     2        5.000
# 6                       Macromedia    19931213  7371   MACR     1       12.000
# 7                          Navarre    19931216  5045   NAVR     1        5.625
# 8      Investment Technology Group    19940504  7379   ITGI     1       13.000
# 9    Netcom On-Line Communications    19941214  5045   NETC     1       13.000
# 10                Infosafe Systems    19950118  5045  ISFEA     2        5.000
# 11             Transaction Systems    19950223  7372   TSAI     1       15.000
# 733                    Stoneco Ltd    20181025  7372   STNE     1       24.000
#
# [734 rows x 6 columns]

# %%
tickers = tickers.sort_values("Offer date", ascending=False).reset_index(drop=True)

# %%
tickers['S1Link'] = ''

# %%
results = tickers.copy()

# %%
for i in tickers.iterrows():
    print(i[1]['IPO name'])
    print(i[1]['Ticker'])
    ticker = i[1]['Ticker']
    result = (get_query(ticker))
    df = json_normalize(result)
    if len(df) != 0:
        df = df[df['formType'] == "S-1"]
        df = df.sort_values("filedAt", ascending=False).reset_index(drop=True)
        secLink = df['linkToHtml'][0]
        index = i[0]
        results.iloc[index, 6] = secLink
        print(secLink)
# Out:
# Cisco Systems
# CSCO
# []
# Valassis Communications
# VCI
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-82-5947d6e1ef76> in <module>()
#       3     print(i[1]['Ticker'])
#       4     ticker = i[1]['Ticker']
# ----> 5     result = (get_query(ticker))
#       6     print(result)
#       7     df = json_normalize(result)
#
# <ipython-input-1-59b487dadfc3> in get_query(ticker)
#      50
#      51     # Send the request to the API
# ---> 52     response = urllib.request.urlopen(req, jsondataasbytes)
#      53
#      54     # Read the response
#
# /Users/sharan/anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /Users/sharan/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /Users/sharan/anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /Users/sharan/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /Users/sharan/anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1360         def https_open(self, req):
#    1361             return self.do_open(http.client.HTTPSConnection, req,
# -> 1362                 context=self._context, check_hostname=self._check_hostname)
#    1363
#    1364         https_request = AbstractHTTPHandler.do_request_
#
# /Users/sharan/anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1320             except OSError as err: # timeout error
#    1321                 raise URLError(err)
# -> 1322             r = h.getresponse()
#    1323         except:
#    1324             h.close()
#
# /Users/sharan/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# /Users/sharan/anaconda3/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# /Users/sharan/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# /Users/sharan/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /Users/sharan/anaconda3/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /Users/sharan/anaconda3/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
results
# Out:
#                           IPO name  Offer date   SIC Ticker  Unit  \
# 0                    Cisco Systems    19900216  3577   CSCO     1
# 1          Valassis Communications    19920311  2752    VCI     1
# 2                   America Online    19920319  4822   AMER     1
# 3                           Olicom    19921022  7372  OLCMF     1
# 4                  Micro Warehouse    19921210  5961   MWHS     1
# 5                      FutureMedia    19930819  7812  FMDAY     2
# 6                       Macromedia    19931213  7371   MACR     1
# 7                          Navarre    19931216  5045   NAVR     1
# 8      Investment Technology Group    19940504  7379   ITGI     1
# 9    Netcom On-Line Communications    19941214  5045   NETC     1
# 10                Infosafe Systems    19950118  5045  ISFEA     2
# 11             Transaction Systems    19950223  7372   TSAI     1
# 12              UUNet Technologies    19950525  7375   UUNT     1
# 13                        Spyglass    19950627  7372   SPYG     1
# 14         Netscape Communications    19950808  7375   NSCP     1
# 15               Tel-Save Holdings    19950920  4813   TALK     1
# 16                          Verity    19951006  7379   VRTY     1
# 17                   ADAM Software    19951110  7371   ADAM     1
# 18                    Kinetiks.com    19951206  7373   KNET     1
# 19                      DeltaPoint    19951220  7372   DTPT     1
# 20              CellularVision USA    19960208  4841   CVUS     1
# 21                       CyberCash    19960215  7379   CYCH     1
# 22               Sterling Commerce    19960308  7372     SE     1
# 23          MindSpring Enterprises    19960314  7389   MSPG     1
# 24                           Lycos    19960401  7379   LCOS     1
# 25                      Excite Inc    19960403  7375   XCIT     1
# 26                          Yahoo!    19960412  7375   YHOO     1
# 27                      CompuServe    19960418  7375   CSRV     1
# 28                     Infonautics    19960429  7375   INFO     1
# 29                   Whittman-Hart    19960503  7379   WHIT     1
# ..                             ...         ...   ...    ...   ...
# 704                   Mimecast Ltd    20151119  7372   MIME     1
# 705                Match Group Inc    20151119  7389   MTCH     1
# 706        BATS Global Markets Inc    20160415  6211   BATS     1
# 707               SecureWorks Corp    20160422  7379   SCWX     1
# 708      Acacia Communications Inc    20160513  3674   ACIA     1
# 709             The Trade Desk Inc    20160921  8742    TTD     1
# 710     Tabula Rasa HealthCare Inc    20160929  8059   TRHC     1
# 711   Quantenna Communications Inc    20161028  7375   QTNA     1
# 712                       Snap Inc    20170302  7372   SNAP     1
# 713                   Presidio Inc    20170310  7376   PSDO     1
# 714          Netshoes (Cayman) Ltd    20170412  5961   NETS     1
# 715                     Carvana Co    20170428  5511   CVNA     1
# 716        Blue Apron Holdings Inc    20170629  5961   APRN     1
# 717                     Tintri Inc    20170630  7375   TNTR     1
# 718                    Redfin Corp    20170728  6531   RDFN     1
# 719              Despegar.com Corp    20170920  4724   DESP     1
# 720                       Roku Inc    20170928  4841   ROKU     1
# 721     Forescout Technologies Inc    20171027  3577   FSCT     1
# 722              Bandwidth.com Inc    20171110  7375   BAND     1
# 723                    Dropbox Inc    20180323  7375    DBX     1
# 724                Pluralsight Inc    20180517  7370     PS     1
# 725                   GreenSky Inc    20180524  7389   GSKY     1
# 726                    Avalara Inc    20180615  7372   AVLR     1
# 727                 Eventbrite Inc    20180920  7372     EB     1
# 728                   Farfetch Ltd    20180921  7389   FTCH     1
# 729                       SVMK Inc    20180926  7374   SVMK     1
# 730                     Upwork Inc    20181003  7374   UPWK     1
# 731                     Elastic NV    20181005  7379   ESTC     1
# 732                    Anaplan Inc    20181012  7376   PLAN     1
# 733                    Stoneco Ltd    20181025  7372   STNE     1
#
#      Offer price S1Link
# 0         18.000   test
# 1         17.000
# 2         11.500
# 3         14.000
# 4         18.000
# 5          5.000
# 6         12.000
# 7          5.625
# 8         13.000
# 9         13.000
# 10         5.000
# 11        15.000
# 12        14.000
# 13        17.000
# 14        28.000
# 15        13.750
# 16        12.000
# 17        12.000
# 18         6.000
# 19         6.000
# 20        15.000
# 21        17.000
# 22        24.000
# 23         8.000
# 24        16.000
# 25        17.000
# 26        13.000
# 27        30.000
# 28        14.000
# 29        16.000
# ..           ...    ...
# 704       10.000
# 705       12.000
# 706       19.000
# 707       14.000
# 708       23.000
# 709       18.000
# 710       12.000
# 711       16.000
# 712       17.000
# 713       14.000
# 714       18.000
# 715       15.000
# 716       10.000
# 717        7.000
# 718       15.000
# 719       26.000
# 720       14.000
# 721       22.000
# 722       20.000
# 723       21.000
# 724       15.000
# 725       23.000
# 726       24.000
# 727       23.000
# 728       20.000
# 729       12.000
# 730       15.000
# 731       36.000
# 732       17.000
# 733       24.000
#
# [734 rows x 7 columns]
